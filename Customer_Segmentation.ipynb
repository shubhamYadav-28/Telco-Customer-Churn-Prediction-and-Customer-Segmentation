# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel("Telco_customer_churn.xlsx")

# %%
df
# Out:
#       CustomerID  Count        Country       State          City  Zip Code  \
# 0     3668-QPYBK      1  United States  California   Los Angeles     90003
# 1     9237-HQITU      1  United States  California   Los Angeles     90005
# 2     9305-CDSKC      1  United States  California   Los Angeles     90006
# 3     7892-POOKP      1  United States  California   Los Angeles     90010
# 4     0280-XJGEX      1  United States  California   Los Angeles     90015
# ...          ...    ...            ...         ...           ...       ...
# 7038  2569-WGERO      1  United States  California       Landers     92285
# 7039  6840-RESVB      1  United States  California      Adelanto     92301
# 7040  2234-XADUH      1  United States  California         Amboy     92304
# 7041  4801-JZAZL      1  United States  California  Angelus Oaks     92305
# 7042  3186-AJIEK      1  United States  California  Apple Valley     92308
#
#                     Lat Long   Latitude   Longitude  Gender  ...  \
# 0     33.964131, -118.272783  33.964131 -118.272783    Male  ...
# 1      34.059281, -118.30742  34.059281 -118.307420  Female  ...
# 2     34.048013, -118.293953  34.048013 -118.293953  Female  ...
# 3     34.062125, -118.315709  34.062125 -118.315709  Female  ...
# 4     34.039224, -118.266293  34.039224 -118.266293    Male  ...
# ...                      ...        ...         ...     ...  ...
# 7038  34.341737, -116.539416  34.341737 -116.539416  Female  ...
# 7039  34.667815, -117.536183  34.667815 -117.536183    Male  ...
# 7040  34.559882, -115.637164  34.559882 -115.637164  Female  ...
# 7041     34.1678, -116.86433  34.167800 -116.864330  Female  ...
# 7042  34.424926, -117.184503  34.424926 -117.184503    Male  ...
#
#             Contract Paperless Billing             Payment Method  \
# 0     Month-to-month               Yes               Mailed check
# 1     Month-to-month               Yes           Electronic check
# 2     Month-to-month               Yes           Electronic check
# 3     Month-to-month               Yes           Electronic check
# 4     Month-to-month               Yes  Bank transfer (automatic)
# ...              ...               ...                        ...
# 7038        Two year               Yes  Bank transfer (automatic)
# 7039        One year               Yes               Mailed check
# 7040        One year               Yes    Credit card (automatic)
# 7041  Month-to-month               Yes           Electronic check
# 7042        Two year               Yes  Bank transfer (automatic)
#
#       Monthly Charges Total Charges Churn Label Churn Value Churn Score  CLTV  \
# 0               53.85        108.15         Yes           1          86  3239
# 1               70.70        151.65         Yes           1          67  2701
# 2               99.65         820.5         Yes           1          86  5372
# 3              104.80       3046.05         Yes           1          84  5003
# 4              103.70        5036.3         Yes           1          89  5340
# ...               ...           ...         ...         ...         ...   ...
# 7038            21.15        1419.4          No           0          45  5306
# 7039            84.80        1990.5          No           0          59  2140
# 7040           103.20        7362.9          No           0          71  5560
# 7041            29.60        346.45          No           0          59  2793
# 7042           105.65        6844.5          No           0          38  5097
#
#                        Churn Reason
# 0      Competitor made better offer
# 1                             Moved
# 2                             Moved
# 3                             Moved
# 4     Competitor had better devices
# ...                             ...
# 7038                            NaN
# 7039                            NaN
# 7040                            NaN
# 7041                            NaN
# 7042                            NaN
#
# [7043 rows x 33 columns]

# %%
df.shape
# Out:
# (7043, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
#  16  Internet Service   7043 non-null   object
#  17  Online Security    7043 non-null   object
#  18  Online Backup      7043 non-null   object
#  19  Device Protection  7043 non-null   object
#  20  Tech Support       7043 non-null   object
#  21  Streaming TV       7043 non-null   object
#  22  Streaming Movies   7043 non-null   object
#  23  Contract           7043 non-null   object
#  24  Paperless Billing  7043 non-null   object
#  25  Payment Method     7043 non-null   object
#  26  Monthly Charges    7043 non-null   float64
#  27  Total Charges      7043 non-null   object
#  28  Churn Label        7043 non-null   object
#  29  Churn Value        7043 non-null   int64
#  30  Churn Score        7043 non-null   int64
#  31  CLTV               7043 non-null   int64
#  32  Churn Reason       1869 non-null   object
# dtypes: float64(3), int64(6), object(24)
# memory usage: 1.8+ MB

# %%
df['Churn Label'].value_counts()
# Out:
# Churn Label
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Tenure Months'] , bins=30,kde=True)
plt.xlabel('Tenure Months')
plt.ylabel('Customer Count')
plt.title('Distribution of Tenure Months Vs Customer Count')
plt.show()

# %%
df['Tenure Months'].max()
# Out:
# 72

# %%
df['Tenure Months'].min()
# Out:
# 0

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x= 'Churn Label',y='Tenure Months', data=df)
plt.xlabel('Churn Label')
plt.ylabel('Tenure Months')
plt.title('Churn Vs Tenure Month')
plt.show()

# %% [markdown]
# Above graph shows- 50% of people are availing the service for almost 38 months and 50% are leaving within 10 months

# %%
df['Churn Label'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df[df['Churn Label']=='Yes']
# Out:
#       CustomerID  Count        Country       State          City  Zip Code  \
# 0     3668-QPYBK      1  United States  California   Los Angeles     90003
# 1     9237-HQITU      1  United States  California   Los Angeles     90005
# 2     9305-CDSKC      1  United States  California   Los Angeles     90006
# 3     7892-POOKP      1  United States  California   Los Angeles     90010
# 4     0280-XJGEX      1  United States  California   Los Angeles     90015
# ...          ...    ...            ...         ...           ...       ...
# 1864  1699-HPSBG      1  United States  California  Palm Springs     92264
# 1865  8775-CEBBJ      1  United States  California        Seeley     92273
# 1866  6894-LFHLY      1  United States  California         Vidal     92280
# 1867  0639-TSIQW      1  United States  California   White Water     92282
# 1868  8361-LTMKD      1  United States  California  Apple Valley     92307
#
#                     Lat Long   Latitude   Longitude  Gender  ...  \
# 0     33.964131, -118.272783  33.964131 -118.272783    Male  ...
# 1      34.059281, -118.30742  34.059281 -118.307420  Female  ...
# 2     34.048013, -118.293953  34.048013 -118.293953  Female  ...
# 3     34.062125, -118.315709  34.062125 -118.315709  Female  ...
# 4     34.039224, -118.266293  34.039224 -118.266293    Male  ...
# ...                      ...        ...         ...     ...  ...
# 1864  33.745746, -116.514215  33.745746 -116.514215    Male  ...
# 1865  32.790282, -115.689559  32.790282 -115.689559  Female  ...
# 1866  34.264124, -114.717964  34.264124 -114.717964    Male  ...
# 1867  33.972293, -116.654195  33.972293 -116.654195  Female  ...
# 1868   34.55082, -117.122396  34.550820 -117.122396    Male  ...
#
#             Contract Paperless Billing             Payment Method  \
# 0     Month-to-month               Yes               Mailed check
# 1     Month-to-month               Yes           Electronic check
# 2     Month-to-month               Yes           Electronic check
# 3     Month-to-month               Yes           Electronic check
# 4     Month-to-month               Yes  Bank transfer (automatic)
# ...              ...               ...                        ...
# 1864        One year               Yes           Electronic check
# 1865  Month-to-month               Yes  Bank transfer (automatic)
# 1866  Month-to-month               Yes           Electronic check
# 1867  Month-to-month               Yes    Credit card (automatic)
# 1868  Month-to-month               Yes               Mailed check
#
#       Monthly Charges Total Charges Churn Label Churn Value Churn Score  CLTV  \
# 0               53.85        108.15         Yes           1          86  3239
# 1               70.70        151.65         Yes           1          67  2701
# 2               99.65         820.5         Yes           1          86  5372
# 3              104.80       3046.05         Yes           1          84  5003
# 4              103.70        5036.3         Yes           1          89  5340
# ...               ...           ...         ...         ...         ...   ...
# 1864            59.80         727.8         Yes           1          69  4581
# 1865            44.20        403.35         Yes           1          87  2029
# 1866            75.75         75.75         Yes           1          97  5571
# 1867           102.95       6886.25         Yes           1          70  5620
# 1868            74.40         306.6         Yes           1          77  5839
#
#                                    Churn Reason
# 0                  Competitor made better offer
# 1                                         Moved
# 2                                         Moved
# 3                                         Moved
# 4                 Competitor had better devices
# ...                                         ...
# 1864  Competitor offered higher download speeds
# 1865  Competitor offered higher download speeds
# 1866  Competitor offered higher download speeds
# 1867               Competitor offered more data
# 1868               Competitor offered more data
#
# [1869 rows x 33 columns]

# %%
# ['Tenure Months'].quantile([0.25,0.50,0.75])

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Monthly Charges'] , bins=30,kde=True)
plt.xlabel('Month Charges')
plt.ylabel('Customer Count')
plt.title('Distribution of Month Charges Vs Customer Count')
plt.show()

# %%
df['Monthly Charges'].max()
# Out:
# 118.75

# %%
df['Monthly Charges'].min()
# Out:
# 18.25

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Churn Label',y='Monthly Charges', data=df)
plt.xlabel('Churn Label')
plt.ylabel('Monthly Charges')
plt.title('Churn rate vs monthly charges')
plt.show()

# %% [markdown]
# Boolean Indexing / Filtering

# %%
df[df['Churn Label'] == 'Yes']['Monthly Charges'].quantile([0.25,0.50,0.75])
# Out:
# 0.25    56.15
# 0.50    79.65
# 0.75    94.20
# Name: Monthly Charges, dtype: float64

# %%
df[df['Churn Label'] == 'No']['Monthly Charges'].quantile([0.25,0.50,0.75])
# Out:
# 0.25    25.100
# 0.50    64.425
# 0.75    88.400
# Name: Monthly Charges, dtype: float64

# %%
df['Monthly Charges'].describe()
# Out:
# count    7043.000000
# mean       64.761692
# std        30.090047
# min        18.250000
# 25%        35.500000
# 50%        70.350000
# 75%        89.850000
# max       118.750000
# Name: Monthly Charges, dtype: float64

# %%
df['Monthly Charges'].quantile([0.25,0.50,0.75])
# Out:
# 0.25    35.50
# 0.50    70.35
# 0.75    89.85
# Name: Monthly Charges, dtype: float64

# %%
df['Contract'].unique()
# Out:
# array(['Month-to-month', 'Two year', 'One year'], dtype=object)

# %% [markdown]
# Without hue

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Contract', data=df)
plt.xlabel('Contract')
plt.ylabel('Count')
plt.title('Contract vs Count')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Contract',hue='Churn Label', data=df)
plt.xlabel('Contract')
plt.ylabel('Count')
plt.title('Contract vs Count')
plt.show()

# %%
df['Contract'].value_counts()
# Out:
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
#  16  Internet Service   7043 non-null   object
#  17  Online Security    7043 non-null   object
#  18  Online Backup      7043 non-null   object
#  19  Device Protection  7043 non-null   object
#  20  Tech Support       7043 non-null   object
#  21  Streaming TV       7043 non-null   object
#  22  Streaming Movies   7043 non-null   object
#  23  Contract           7043 non-null   object
#  24  Paperless Billing  7043 non-null   object
#  25  Payment Method     7043 non-null   object
#  26  Monthly Charges    7043 non-null   float64
#  27  Total Charges      7043 non-null   object
#  28  Churn Label        7043 non-null   object
#  29  Churn Value        7043 non-null   int64
#  30  Churn Score        7043 non-null   int64
#  31  CLTV               7043 non-null   int64
#  32  Churn Reason       1869 non-null   object
# dtypes: float64(3), int64(6), object(24)
# memory usage: 1.8+ MB

# %%
df['Internet Service'].unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Internet Service',hue='Churn Label', data=df)
plt.xlabel('Internet Service')
plt.ylabel('Count')
plt.title('Internet Service vs Count')
plt.show()

# %%
df['Payment Method'].unique()
# Out:
# array(['Mailed check', 'Electronic check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Payment Method',hue='Churn Label', data=df)
plt.xlabel('Payment Method')
plt.ylabel('Count')
plt.title('Payment Method vs Count')
plt.show()

# %%
df['Tech Support'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Tech Support',hue='Churn Label', data=df)
plt.xlabel('Tech Support')
plt.ylabel('Count')
plt.title('Tech Support vs Count')
plt.show()

# %%
avg_tenure=df.groupby('Churn Label')['Tenure Months'].mean()
avg_tenure
# Out:
# Churn Label
# No     37.569965
# Yes    17.979133
# Name: Tenure Months, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
#  16  Internet Service   7043 non-null   object
#  17  Online Security    7043 non-null   object
#  18  Online Backup      7043 non-null   object
#  19  Device Protection  7043 non-null   object
#  20  Tech Support       7043 non-null   object
#  21  Streaming TV       7043 non-null   object
#  22  Streaming Movies   7043 non-null   object
#  23  Contract           7043 non-null   object
#  24  Paperless Billing  7043 non-null   object
#  25  Payment Method     7043 non-null   object
#  26  Monthly Charges    7043 non-null   float64
#  27  Total Charges      7043 non-null   object
#  28  Churn Label        7043 non-null   object
#  29  Churn Value        7043 non-null   int64
#  30  Churn Score        7043 non-null   int64
#  31  CLTV               7043 non-null   int64
#  32  Churn Reason       1869 non-null   object
# dtypes: float64(3), int64(6), object(24)
# memory usage: 1.8+ MB

# %%
numerical_cols=['Tenure Months','Monthly Charges','Churn Value','Churn Score','CLTV']
correlation_matrix=df[numerical_cols].corr()

# %%
correlation_matrix
# Out:
#                  Tenure Months  Monthly Charges  Churn Value  Churn Score  \
# Tenure Months         1.000000         0.247900    -0.352229    -0.224987
# Monthly Charges       0.247900         1.000000     0.193356     0.133754
# Churn Value          -0.352229         0.193356     1.000000     0.664897
# Churn Score          -0.224987         0.133754     0.664897     1.000000
# CLTV                  0.396406         0.098693    -0.127463    -0.079782
#
#                      CLTV
# Tenure Months    0.396406
# Monthly Charges  0.098693
# Churn Value     -0.127463
# Churn Score     -0.079782
# CLTV             1.000000

# %%
Contract_churn=pd.crosstab(df['Contract'],df['Churn Label'])
Contract_churn
# Out:
# Churn Label       No   Yes
# Contract
# Month-to-month  2220  1655
# One year        1307   166
# Two year        1647    48

# %%
Contract_churn_percent=pd.crosstab(df['Contract'],df['Churn Label'],normalize='index')
Contract_churn_percent
# Out:
# Churn Label           No       Yes
# Contract
# Month-to-month  0.572903  0.427097
# One year        0.887305  0.112695
# Two year        0.971681  0.028319

# %% [markdown]
# **DATA CLEANING**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
#  16  Internet Service   7043 non-null   object
#  17  Online Security    7043 non-null   object
#  18  Online Backup      7043 non-null   object
#  19  Device Protection  7043 non-null   object
#  20  Tech Support       7043 non-null   object
#  21  Streaming TV       7043 non-null   object
#  22  Streaming Movies   7043 non-null   object
#  23  Contract           7043 non-null   object
#  24  Paperless Billing  7043 non-null   object
#  25  Payment Method     7043 non-null   object
#  26  Monthly Charges    7043 non-null   float64
#  27  Total Charges      7043 non-null   object
#  28  Churn Label        7043 non-null   object
#  29  Churn Value        7043 non-null   int64
#  30  Churn Score        7043 non-null   int64
#  31  CLTV               7043 non-null   int64
#  32  Churn Reason       1869 non-null   object
# dtypes: float64(3), int64(6), object(24)
# memory usage: 1.8+ MB

# %%
df['Total Charges']
# Out:
# 0        108.15
# 1        151.65
# 2         820.5
# 3       3046.05
# 4        5036.3
#          ...
# 7038     1419.4
# 7039     1990.5
# 7040     7362.9
# 7041     346.45
# 7042     6844.5
# Name: Total Charges, Length: 7043, dtype: object

# %%
df['Total Charges']=pd.to_numeric(df['Total Charges'],errors='coerce')

# %%
df['Total Charges']
# Out:
# 0        108.15
# 1        151.65
# 2        820.50
# 3       3046.05
# 4       5036.30
#          ...
# 7038    1419.40
# 7039    1990.50
# 7040    7362.90
# 7041     346.45
# 7042    6844.50
# Name: Total Charges, Length: 7043, dtype: float64

# %%
df['Total Charges'].dtype
# Out:
# dtype('float64')

# %%
df['Total Charges'].isnull().sum()
# Out:
# np.int64(11)

# %%
df[df['Total Charges'].isnull()]['Tenure Months']
# Out:
# 2234    0
# 2438    0
# 2568    0
# 2667    0
# 2856    0
# 4331    0
# 4687    0
# 5104    0
# 5719    0
# 6772    0
# 6840    0
# Name: Tenure Months, dtype: int64

# %%
df[df['Total Charges'].isnull()]['Tenure Months'].shape
# Out:
# (11,)

# %%
df['Total Charges']= df['Total Charges'].fillna(0)

# %%
df['Total Charges'].isnull().sum()
# Out:
# np.int64(0)

# %%
drop_columns = [
    'CustomerID','Count','Country','State','Zip Code','Lat Long','Latitude','Longitude','Churn Label','Churn Score','CLTV','Churn Reason'
]
df = df.drop(columns=drop_columns)

# %%
df.shape
# Out:
# (7043, 21)

# %%
df['City'].unique
df['City'].value_counts()
# Out:
# City
# Los Angeles      305
# San Diego        150
# San Jose         112
# Sacramento       108
# San Francisco    104
#                 ...
# Chester            4
# Big Bar            4
# Washington         4
# Stonyford          4
# Stirling City      4
# Name: count, Length: 1129, dtype: int64

# %%
df_encoded= pd.get_dummies(df,drop_first=True)

# %%
df_encoded.head()
# Out:
#    Tenure Months  Monthly Charges  Total Charges  Churn Value  City_Acton  \
# 0              2            53.85         108.15            1       False
# 1              2            70.70         151.65            1       False
# 2              8            99.65         820.50            1       False
# 3             28           104.80        3046.05            1       False
# 4             49           103.70        5036.30            1       False
#
#    City_Adelanto  City_Adin  City_Agoura Hills  City_Aguanga  City_Ahwahnee  \
# 0          False      False              False         False          False
# 1          False      False              False         False          False
# 2          False      False              False         False          False
# 3          False      False              False         False          False
# 4          False      False              False         False          False
#
#    ...  Streaming TV_No internet service  Streaming TV_Yes  \
# 0  ...                             False             False
# 1  ...                             False             False
# 2  ...                             False              True
# 3  ...                             False              True
# 4  ...                             False              True
#
#    Streaming Movies_No internet service  Streaming Movies_Yes  \
# 0                                 False                 False
# 1                                 False                 False
# 2                                 False                  True
# 3                                 False                  True
# 4                                 False                  True
#
#    Contract_One year  Contract_Two year  Paperless Billing_Yes  \
# 0              False              False                   True
# 1              False              False                   True
# 2              False              False                   True
# 3              False              False                   True
# 4              False              False                   True
#
#    Payment Method_Credit card (automatic)  Payment Method_Electronic check  \
# 0                                   False                            False
# 1                                   False                             True
# 2                                   False                             True
# 3                                   False                             True
# 4                                   False                            False
#
#    Payment Method_Mailed check
# 0                         True
# 1                        False
# 2                        False
# 3                        False
# 4                        False
#
# [5 rows x 1159 columns]

# %%
df_encoded.shape
# Out:
# (7043, 1159)

# %%
df=df.drop(columns=['City'])

# %%
df_encoded= pd.get_dummies(df,drop_first=True)

# %%
df_encoded.shape
# Out:
# (7043, 31)

# %%
df_encoded
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Churn Value  Gender_Male  \
# 0                 2            53.85         108.15            1         True
# 1                 2            70.70         151.65            1        False
# 2                 8            99.65         820.50            1        False
# 3                28           104.80        3046.05            1        False
# 4                49           103.70        5036.30            1         True
# ...             ...              ...            ...          ...          ...
# 7038             72            21.15        1419.40            0        False
# 7039             24            84.80        1990.50            0         True
# 7040             72           103.20        7362.90            0        False
# 7041             11            29.60         346.45            0        False
# 7042             66           105.65        6844.50            0         True
#
#       Senior Citizen_Yes  Partner_Yes  Dependents_Yes  Phone Service_Yes  \
# 0                  False        False           False               True
# 1                  False        False            True               True
# 2                  False        False            True               True
# 3                  False         True            True               True
# 4                  False        False            True               True
# ...                  ...          ...             ...                ...
# 7038               False        False           False               True
# 7039               False         True            True               True
# 7040               False         True            True               True
# 7041               False         True            True              False
# 7042               False        False           False               True
#
#       Multiple Lines_No phone service  ...  Streaming TV_No internet service  \
# 0                               False  ...                             False
# 1                               False  ...                             False
# 2                               False  ...                             False
# 3                               False  ...                             False
# 4                               False  ...                             False
# ...                               ...  ...                               ...
# 7038                            False  ...                              True
# 7039                            False  ...                             False
# 7040                            False  ...                             False
# 7041                             True  ...                             False
# 7042                            False  ...                             False
#
#       Streaming TV_Yes  Streaming Movies_No internet service  \
# 0                False                                 False
# 1                False                                 False
# 2                 True                                 False
# 3                 True                                 False
# 4                 True                                 False
# ...                ...                                   ...
# 7038             False                                  True
# 7039              True                                 False
# 7040              True                                 False
# 7041             False                                 False
# 7042              True                                 False
#
#       Streaming Movies_Yes  Contract_One year  Contract_Two year  \
# 0                    False              False              False
# 1                    False              False              False
# 2                     True              False              False
# 3                     True              False              False
# 4                     True              False              False
# ...                    ...                ...                ...
# 7038                 False              False               True
# 7039                  True               True              False
# 7040                  True               True              False
# 7041                 False              False              False
# 7042                  True              False               True
#
#       Paperless Billing_Yes  Payment Method_Credit card (automatic)  \
# 0                      True                                   False
# 1                      True                                   False
# 2                      True                                   False
# 3                      True                                   False
# 4                      True                                   False
# ...                     ...                                     ...
# 7038                   True                                   False
# 7039                   True                                   False
# 7040                   True                                    True
# 7041                   True                                   False
# 7042                   True                                   False
#
#       Payment Method_Electronic check  Payment Method_Mailed check
# 0                               False                         True
# 1                                True                        False
# 2                                True                        False
# 3                                True                        False
# 4                               False                        False
# ...                               ...                          ...
# 7038                            False                        False
# 7039                            False                         True
# 7040                            False                        False
# 7041                             True                        False
# 7042                            False                        False
#
# [7043 rows x 31 columns]

# %%
X=df_encoded.drop(columns=['Churn Value'],axis=1)
y=df_encoded['Churn Value']

# %%
X.shape
y.shape
# Out:
# (7043,)

# %%
print(X)
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Gender_Male  \
# 0                 2            53.85         108.15         True
# 1                 2            70.70         151.65        False
# 2                 8            99.65         820.50        False
# 3                28           104.80        3046.05        False
# 4                49           103.70        5036.30         True
# ...             ...              ...            ...          ...
# 7038             72            21.15        1419.40        False
# 7039             24            84.80        1990.50         True
# 7040             72           103.20        7362.90        False
# 7041             11            29.60         346.45        False
# 7042             66           105.65        6844.50         True
#
#       Senior Citizen_Yes  Partner_Yes  Dependents_Yes  Phone Service_Yes  \
# 0                  False        False           False               True
# 1                  False        False            True               True
# 2                  False        False            True               True
# 3                  False         True            True               True
# 4                  False        False            True               True
# ...                  ...          ...             ...                ...
# 7038               False        False           False               True
# 7039               False         True            True               True
# 7040               False         True            True               True
# 7041               False         True            True              False
# 7042               False        False           False               True
#
#       Multiple Lines_No phone service  Multiple Lines_Yes  ...  \
# 0                               False               False  ...
# 1                               False               False  ...
# 2                               False                True  ...
# 3                               False                True  ...
# 4                               False                True  ...
# ...                               ...                 ...  ...
# 7038                            False               False  ...
# 7039                            False                True  ...
# 7040                            False                True  ...
# 7041                             True               False  ...
# 7042                            False               False  ...
#
#       Streaming TV_No internet service  Streaming TV_Yes  \
# 0                                False             False
# 1                                False             False
# 2                                False              True
# 3                                False              True
# 4                                False              True
# ...                                ...               ...
# 7038                              True             False
# 7039                             False              True
# 7040                             False              True
# 7041                             False             False
# 7042                             False              True
#
#       Streaming Movies_No internet service  Streaming Movies_Yes  \
# 0                                    False                 False
# 1                                    False                 False
# 2                                    False                  True
# 3                                    False                  True
# 4                                    False                  True
# ...                                    ...                   ...
# 7038                                  True                 False
# 7039                                 False                  True
# 7040                                 False                  True
# 7041                                 False                 False
# 7042                                 False                  True
#
#       Contract_One year  Contract_Two year  Paperless Billing_Yes  \
# 0                 False              False                   True
# 1                 False              False                   True
# 2                 False              False                   True
# 3                 False              False                   True
# 4                 False              False                   True
# ...                 ...                ...                    ...
# 7038              False               True                   True
# 7039               True              False                   True
# 7040               True              False                   True
# 7041              False              False                   True
# 7042              False               True                   True
#
#       Payment Method_Credit card (automatic)  Payment Method_Electronic check  \
# 0                                      False                            False
# 1                                      False                             True
# 2                                      False                             True
# 3                                      False                             True
# 4                                      False                            False
# ...                                      ...                              ...
# 7038                                   False                            False
# 7039                                   False                            False
# 7040                                    True                            False
# 7041                                   False                             True
# 7042                                   False                            False
#
#       Payment Method_Mailed check
# 0                            True
# 1                           False
# 2                           False
# 3                           False
# 4                           False
# ...                           ...
# 7038                        False
# 7039                         True
# 7040                        False
# 7041                        False
# 7042                        False
#
# [7043 rows x 30 columns]

# %%
print(y)
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    0
# 7042    0
# Name: Churn Value, Length: 7043, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=42)

# %%
X_train.shape
# Out:
# (5634, 30)

# %%
X_test.shape
# Out:
# (1409, 30)

# %%
X_train
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Gender_Male  \
# 2142             71            98.65        6962.85         True
# 1623             16            93.20        1573.70        False
# 6074             32           104.05        3416.85        False
# 1362             24            40.65         933.30        False
# 6754             20            20.05         406.05        False
# ...             ...              ...            ...          ...
# 3772             42           100.40        4303.65        False
# 5191             39            20.70         762.45        False
# 5226             19            20.20         387.40         True
# 5390             35            19.90         666.00         True
# 860              31           103.45        3066.45         True
#
#       Senior Citizen_Yes  Partner_Yes  Dependents_Yes  Phone Service_Yes  \
# 2142               False         True           False               True
# 1623               False        False           False               True
# 6074               False        False           False               True
# 1362                True         True           False              False
# 6754               False         True            True               True
# ...                  ...          ...             ...                ...
# 3772               False         True            True               True
# 5191               False        False           False               True
# 5226               False         True            True               True
# 5390               False         True            True               True
# 860                False        False           False               True
#
#       Multiple Lines_No phone service  Multiple Lines_Yes  ...  \
# 2142                            False                True  ...
# 1623                            False               False  ...
# 6074                            False                True  ...
# 1362                             True               False  ...
# 6754                            False               False  ...
# ...                               ...                 ...  ...
# 3772                            False               False  ...
# 5191                            False               False  ...
# 5226                            False               False  ...
# 5390                            False               False  ...
# 860                             False                True  ...
#
#       Streaming TV_No internet service  Streaming TV_Yes  \
# 2142                             False              True
# 1623                             False             False
# 6074                             False              True
# 1362                             False             False
# 6754                              True             False
# ...                                ...               ...
# 3772                             False              True
# 5191                              True             False
# 5226                              True             False
# 5390                              True             False
# 860                              False              True
#
#       Streaming Movies_No internet service  Streaming Movies_Yes  \
# 2142                                 False                  True
# 1623                                 False                  True
# 6074                                 False                  True
# 1362                                 False                  True
# 6754                                  True                 False
# ...                                    ...                   ...
# 3772                                 False                  True
# 5191                                  True                 False
# 5226                                  True                 False
# 5390                                  True                 False
# 860                                  False                  True
#
#       Contract_One year  Contract_Two year  Paperless Billing_Yes  \
# 2142               True              False                   True
# 1623              False              False                   True
# 6074               True              False                   True
# 1362              False              False                   True
# 6754              False              False                  False
# ...                 ...                ...                    ...
# 3772              False               True                   True
# 5191              False               True                  False
# 5226              False               True                  False
# 5390               True              False                  False
# 860                True              False                   True
#
#       Payment Method_Credit card (automatic)  Payment Method_Electronic check  \
# 2142                                    True                            False
# 1623                                    True                            False
# 6074                                    True                            False
# 1362                                    True                            False
# 6754                                   False                            False
# ...                                      ...                              ...
# 3772                                   False                             True
# 5191                                    True                            False
# 5226                                   False                            False
# 5390                                   False                             True
# 860                                    False                             True
#
#       Payment Method_Mailed check
# 2142                        False
# 1623                        False
# 6074                        False
# 1362                        False
# 6754                         True
# ...                           ...
# 3772                        False
# 5191                        False
# 5226                         True
# 5390                        False
# 860                         False
#
# [5634 rows x 30 columns]

# %%
X_test
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Gender_Male  \
# 185              15            85.90        1269.55        False
# 2715             18            56.80        1074.65         True
# 3825              2            20.00          40.90        False
# 1807              6            84.20         519.15         True
# 132              40           104.80        4131.95         True
# ...             ...              ...            ...          ...
# 6366             66           104.90        6891.45        False
# 315              19            86.00        1532.45         True
# 2439              2            90.35         190.50        False
# 5002             68           110.20        7467.50         True
# 1161             30            99.70        2967.35        False
#
#       Senior Citizen_Yes  Partner_Yes  Dependents_Yes  Phone Service_Yes  \
# 185                False        False           False               True
# 2715               False         True           False               True
# 3825               False        False           False               True
# 1807                True         True           False               True
# 132                False        False           False               True
# ...                  ...          ...             ...                ...
# 6366                True         True            True               True
# 315                False        False           False               True
# 2439               False         True           False               True
# 5002               False         True            True               True
# 1161                True        False           False               True
#
#       Multiple Lines_No phone service  Multiple Lines_Yes  ...  \
# 185                             False               False  ...
# 2715                            False                True  ...
# 3825                            False               False  ...
# 1807                            False               False  ...
# 132                             False                True  ...
# ...                               ...                 ...  ...
# 6366                            False                True  ...
# 315                             False                True  ...
# 2439                            False               False  ...
# 5002                            False                True  ...
# 1161                            False                True  ...
#
#       Streaming TV_No internet service  Streaming TV_Yes  \
# 185                              False             False
# 2715                             False             False
# 3825                              True             False
# 1807                             False             False
# 132                              False              True
# ...                                ...               ...
# 6366                             False              True
# 315                              False             False
# 2439                             False              True
# 5002                             False              True
# 1161                             False              True
#
#       Streaming Movies_No internet service  Streaming Movies_Yes  \
# 185                                  False                  True
# 2715                                 False                 False
# 3825                                  True                 False
# 1807                                 False                  True
# 132                                  False                  True
# ...                                    ...                   ...
# 6366                                 False                  True
# 315                                  False                  True
# 2439                                 False                 False
# 5002                                 False                  True
# 1161                                 False                  True
#
#       Contract_One year  Contract_Two year  Paperless Billing_Yes  \
# 185               False              False                   True
# 2715              False              False                  False
# 3825              False              False                   True
# 1807              False              False                   True
# 132               False              False                  False
# ...                 ...                ...                    ...
# 6366               True              False                   True
# 315               False              False                   True
# 2439              False              False                  False
# 5002              False               True                   True
# 1161              False              False                   True
#
#       Payment Method_Credit card (automatic)  Payment Method_Electronic check  \
# 185                                    False                            False
# 2715                                    True                            False
# 3825                                   False                            False
# 1807                                   False                             True
# 132                                    False                            False
# ...                                      ...                              ...
# 6366                                   False                             True
# 315                                    False                            False
# 2439                                   False                             True
# 5002                                   False                             True
# 1161                                   False                             True
#
#       Payment Method_Mailed check
# 185                         False
# 2715                        False
# 3825                         True
# 1807                        False
# 132                         False
# ...                           ...
# 6366                        False
# 315                         False
# 2439                        False
# 5002                        False
# 1161                        False
#
# [1409 rows x 30 columns]

# %%
y_train.shape
# Out:
# (5634,)

# %%
y_test.shape
# Out:
# (1409,)

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(n_estimators=100,random_state=42)
rf_model.fit(X_train,y_train)
y_pred = rf_model.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 1, 0, 1])

# %%
y_test
# Out:
# 185     1
# 2715    0
# 3825    0
# 1807    1
# 132     1
#        ..
# 6366    0
# 315     1
# 2439    0
# 5002    0
# 1161    1
# Name: Churn Value, Length: 1409, dtype: int64

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.7856635911994322

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_pred)
# Out:
# array([[902, 107],
#        [195, 205]])

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.89      0.86      1009
#            1       0.66      0.51      0.58       400
#
#     accuracy                           0.79      1409
#    macro avg       0.74      0.70      0.72      1409
# weighted avg       0.78      0.79      0.78      1409

# %% [markdown]
# **APPROACH - 1 HANDLE CLASS IMBALANCE**

# %%
rf_balanced = RandomForestClassifier(n_estimators=100,class_weight='balanced',random_state=42)
rf_balanced.fit(X_train,y_train)
y_pred_balanced = rf_balanced.predict(X_test)
accuracy_balanced = accuracy_score(y_test,y_pred_balanced)
print(accuracy_balanced)
# Out:
# 0.7920511000709723

# %%
cm_balanced = confusion_matrix(y_test,y_pred_balanced)
print(cm_balanced)
# Out:
# [[907 102]
#  [191 209]]

# %%
print(classification_report(y_test,y_pred_balanced))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.86      1009
#            1       0.67      0.52      0.59       400
#
#     accuracy                           0.79      1409
#    macro avg       0.75      0.71      0.72      1409
# weighted avg       0.78      0.79      0.78      1409

# %% [markdown]
# **APPROACH -2 HYPERPARAMETER TUNING**

# %%
rf_tuned=RandomForestClassifier(n_estimators=300,max_depth= 10,random_state=42,class_weight='balanced')
rf_tuned.fit(X_train,y_train)

y_pred_tuned = rf_tuned.predict(X_test)

accuracy_tuned = accuracy_score(y_test, y_pred_tuned)
print(accuracy_balanced)

cm_tuned = confusion_matrix(y_test, y_pred_tuned)
print(cm_tuned)


print (classification_report(y_test, y_pred_tuned))
# Out:
# 0.7920511000709723
# [[804 205]
#  [101 299]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84      1009
#            1       0.59      0.75      0.66       400
#
#     accuracy                           0.78      1409
#    macro avg       0.74      0.77      0.75      1409
# weighted avg       0.80      0.78      0.79      1409

# %% [markdown]
# **APPROACH - 3 FEATURE IMPORTANCE ANALYSIS**

# %%
import pandas as pd
features_importances_ = pd.DataFrame({
    'Features':X.columns,
    'Importance':rf_tuned.feature_importances_,
    })
features_importances= features_importances_.sort_values(by='Importance',ascending=False)
print(features_importances)
# Out:
#                                   Features  Importance
# 0                            Tenure Months    0.179069
# 2                            Total Charges    0.136460
# 25                       Contract_Two year    0.102861
# 1                          Monthly Charges    0.093681
# 6                           Dependents_Yes    0.068517
# 10            Internet Service_Fiber optic    0.060228
# 28         Payment Method_Electronic check    0.046732
# 24                       Contract_One year    0.036682
# 13                     Online Security_Yes    0.029356
# 19                        Tech Support_Yes    0.021106
# 26                   Paperless Billing_Yes    0.018064
# 5                              Partner_Yes    0.015846
# 12     Online Security_No internet service    0.014973
# 18        Tech Support_No internet service    0.014799
# 22    Streaming Movies_No internet service    0.014360
# 16   Device Protection_No internet service    0.012985
# 11                     Internet Service_No    0.012673
# 3                              Gender_Male    0.012586
# 15                       Online Backup_Yes    0.012213
# 9                       Multiple Lines_Yes    0.011690
# 14       Online Backup_No internet service    0.010298
# 4                       Senior Citizen_Yes    0.010257
# 20        Streaming TV_No internet service    0.010186
# 23                    Streaming Movies_Yes    0.010161
# 27  Payment Method_Credit card (automatic)    0.009430
# 21                        Streaming TV_Yes    0.009289
# 17                   Device Protection_Yes    0.009101
# 29             Payment Method_Mailed check    0.008800
# 7                        Phone Service_Yes    0.003872
# 8          Multiple Lines_No phone service    0.003725

# %%
print(features_importances.tail(15))
# Out:
#                                   Features  Importance
# 16   Device Protection_No internet service    0.012985
# 11                     Internet Service_No    0.012673
# 3                              Gender_Male    0.012586
# 15                       Online Backup_Yes    0.012213
# 9                       Multiple Lines_Yes    0.011690
# 14       Online Backup_No internet service    0.010298
# 4                       Senior Citizen_Yes    0.010257
# 20        Streaming TV_No internet service    0.010186
# 23                    Streaming Movies_Yes    0.010161
# 27  Payment Method_Credit card (automatic)    0.009430
# 21                        Streaming TV_Yes    0.009289
# 17                   Device Protection_Yes    0.009101
# 29             Payment Method_Mailed check    0.008800
# 7                        Phone Service_Yes    0.003872
# 8          Multiple Lines_No phone service    0.003725

# %%
X_selected = X.drop(['Phone Service_Yes','Multiple Lines_No phone service'],axis = 1)

# %%
X_train_sel,X_test_sel,y_train_sel,y_test_sel = train_test_split(X_selected,y,test_size=0.20,random_state=42)

# %%
rf_selected = RandomForestClassifier(n_estimators=300,max_depth= 10,random_state=42,class_weight='balanced')
rf_selected.fit(X_train_sel,y_train_sel)
y_pred_selected = rf_selected.predict(X_test_sel)

print (classification_report(y_test_sel, y_pred_selected))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84      1009
#            1       0.60      0.74      0.66       400
#
#     accuracy                           0.78      1409
#    macro avg       0.74      0.77      0.75      1409
# weighted avg       0.80      0.78      0.79      1409

# %% [markdown]
# **APPROACH - 2 COMBINATION OF TREES AND DEPTH**

# %%
from sklearn.metrics import accuracy_score,recall_score,precision_score ,f1_score
rf_selected=RandomForestClassifier(n_estimators=300,max_depth=10,random_state=42,class_weight='balanced')
rf_selected.fit(X_train_sel,y_train_sel)
y_pred_selected=rf_selected.predict(X_test_sel)

print (classification_report(y_test_sel, y_pred_selected))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84      1009
#            1       0.60      0.74      0.66       400
#
#     accuracy                           0.78      1409
#    macro avg       0.74      0.77      0.75      1409
# weighted avg       0.80      0.78      0.79      1409

# %%
n_estimators_list=[100,200,300,400,500]
max_depth_list = [5,10,15,20]
results = []
for n_trees in n_estimators_list:
  for depth in max_depth_list:
    rf = RandomForestClassifier(n_estimators=n_trees,
                                    max_depth=depth,
                                    class_weight='balanced'
                                    )

    rf.fit(X_train,y_train)
    y_pred = rf.predict(X_test)
    accuracy = accuracy_score(y_test,y_pred)
    recall = recall_score(y_test,y_pred)
    precision = precision_score(y_test,y_pred)
    f1 = f1_score(y_test,y_pred)
    results.append({'Trees':n_trees,'Depth':depth,'Accuracy':accuracy,'Recall':recall,'Precision':precision,'F1_score':f1_score})
result_df = pd.DataFrame(results)
result_df = result_df.sort_values(by=['Recall','Accuracy'],ascending=False)
print(result_df.head(20))
# Out:
#     Trees  Depth  Accuracy  Recall  Precision  \
# 8     300      5  0.740951  0.8025   0.528830
# 4     200      5  0.744500  0.8000   0.533333
# 12    400      5  0.744500  0.8000   0.533333
# 0     100      5  0.744500  0.7975   0.533445
# 16    500      5  0.738112  0.7975   0.525535
# 1     100     10  0.789212  0.7575   0.602386
# 5     200     10  0.782115  0.7500   0.591716
# 17    500     10  0.783534  0.7475   0.594433
# 9     300     10  0.779986  0.7450   0.588933
# 13    400     10  0.782825  0.7425   0.594000
# 2     100     15  0.807665  0.6450   0.666667
# 10    300     15  0.799148  0.6375   0.648855
# 6     200     15  0.805536  0.6325   0.665789
# 14    400     15  0.801278  0.6300   0.656250
# 18    500     15  0.800568  0.6250   0.656168
# 7     200     20  0.794180  0.5325   0.674051
# 19    500     20  0.794180  0.5325   0.674051
# 15    400     20  0.794180  0.5250   0.677419
# 11    300     20  0.793471  0.5225   0.676375
# 3     100     20  0.793471  0.5100   0.682274
#
#                                  F1_score
# 8   <function f1_score at 0x7d90768e3740>
# 4   <function f1_score at 0x7d90768e3740>
# 12  <function f1_score at 0x7d90768e3740>
# 0   <function f1_score at 0x7d90768e3740>
# 16  <function f1_score at 0x7d90768e3740>
# 1   <function f1_score at 0x7d90768e3740>
# 5   <function f1_score at 0x7d90768e3740>
# 17  <function f1_score at 0x7d90768e3740>
# 9   <function f1_score at 0x7d90768e3740>
# 13  <function f1_score at 0x7d90768e3740>
# 2   <function f1_score at 0x7d90768e3740>
# 10  <function f1_score at 0x7d90768e3740>
# 6   <function f1_score at 0x7d90768e3740>
# 14  <function f1_score at 0x7d90768e3740>
# 18  <function f1_score at 0x7d90768e3740>
# 7   <function f1_score at 0x7d90768e3740>
# 19  <function f1_score at 0x7d90768e3740>
# 15  <function f1_score at 0x7d90768e3740>
# 11  <function f1_score at 0x7d90768e3740>
# 3   <function f1_score at 0x7d90768e3740>

# %%
from sklearn.model_selection import cross_val_score
final_rf = RandomForestClassifier(n_estimators=300,max_depth=10,random_state=42,class_weight='balanced')
cv_accuracy = cross_val_score(final_rf,X,y,cv=5,scoring='accuracy')
print(cv_accuracy)
print(cv_accuracy.mean())
# Out:
# [0.76721079 0.79772889 0.76224273 0.78551136 0.78409091]
# 0.7793569343183432

# %%
cv_recall= cross_val_score(final_rf,X,y,cv=5,scoring='recall')
print(cv_recall)
print(cv_recall.mean())
# Out:
# [0.70855615 0.76470588 0.74064171 0.74331551 0.71045576]
# 0.7335350030823931

# %% [markdown]
# **OPTIONAL**

# %%
from sklearn.metrics import roc_auc_score,roc_curve
import matplotlib.pyplot as plt

# %%
y_pred1 = rf_tuned.predict_proba(X_test)

# %%
y_pred = rf_tuned.predict_proba(X)

# %%
churn_prob = y_pred1[:,1]
fpr,tpr,threshold = roc_curve(y_test,churn_prob)
auc_score = roc_auc_score(y_test,churn_prob)
print(auc_score)
# Out:
# 0.857104806739346

# %% [markdown]
# **CUSTOMER SEGMENTATION**

# %%
segmentation_data = pd.DataFrame({'Tenure Months':X['Tenure Months'],
                                'Monthly Charges':X['Monthly Charges'],
                                'Total Charges':X['Total Charges'],
                                'Churn Probability':y_pred[:,1]})
print(segmentation_data)
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Churn Probability
# 0                 2            53.85         108.15           0.676963
# 1                 2            70.70         151.65           0.796013
# 2                 8            99.65         820.50           0.805827
# 3                28           104.80        3046.05           0.563031
# 4                49           103.70        5036.30           0.517474
# ...             ...              ...            ...                ...
# 7038             72            21.15        1419.40           0.003587
# 7039             24            84.80        1990.50           0.082095
# 7040             72           103.20        7362.90           0.049001
# 7041             11            29.60         346.45           0.302367
# 7042             66           105.65        6844.50           0.257647
#
# [7043 rows x 4 columns]

# %% [markdown]
# **IMPLEMENTATION OF KMEANS**

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
scaled_data = scaler.fit_transform(segmentation_data)

# %%
print(scaled_data[:5])
# Out:
# [[-1.23672422 -0.36266036 -0.9580659   1.02486837]
#  [-1.23672422  0.19736523 -0.93887444  1.4138535 ]
#  [-0.99240204  1.1595457  -0.64378925  1.44591771]
#  [-0.17799476  1.33071079  0.3380854   0.65260685]
#  [ 0.67713287  1.29415125  1.2161497   0.50375182]]

# %%
from sklearn.cluster import KMeans
wcss=[]
for k in range(1,16):
  kmeans = KMeans(n_clusters=k,random_state=42)
  kmeans.fit(scaled_data)
  wcss.append(kmeans.inertia_)
  plt.figure(figsize=(8,6))
plt.plot(range(1,16),wcss ,marker='o')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.title('Elbow Method')
plt.show()

# %%
kmeans = KMeans(n_clusters=3,random_state=42)

# %%
clusters=kmeans.fit_predict(scaled_data)

# %%
segmentation_data
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Churn Probability
# 0                 2            53.85         108.15           0.676963
# 1                 2            70.70         151.65           0.796013
# 2                 8            99.65         820.50           0.805827
# 3                28           104.80        3046.05           0.563031
# 4                49           103.70        5036.30           0.517474
# ...             ...              ...            ...                ...
# 7038             72            21.15        1419.40           0.003587
# 7039             24            84.80        1990.50           0.082095
# 7040             72           103.20        7362.90           0.049001
# 7041             11            29.60         346.45           0.302367
# 7042             66           105.65        6844.50           0.257647
#
# [7043 rows x 4 columns]

# %%
segmentation_data['Cluster']=clusters

# %%
segmentation_data
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Churn Probability  \
# 0                 2            53.85         108.15           0.676963
# 1                 2            70.70         151.65           0.796013
# 2                 8            99.65         820.50           0.805827
# 3                28           104.80        3046.05           0.563031
# 4                49           103.70        5036.30           0.517474
# ...             ...              ...            ...                ...
# 7038             72            21.15        1419.40           0.003587
# 7039             24            84.80        1990.50           0.082095
# 7040             72           103.20        7362.90           0.049001
# 7041             11            29.60         346.45           0.302367
# 7042             66           105.65        6844.50           0.257647
#
#       Cluster
# 0           1
# 1           1
# 2           1
# 3           1
# 4           2
# ...       ...
# 7038        0
# 7039        0
# 7040        2
# 7041        0
# 7042        2
#
# [7043 rows x 5 columns]

# %%
cluster_summary=segmentation_data.groupby('Cluster').mean()

# %%
cluster_summary
# Out:
#          Tenure Months  Monthly Charges  Total Charges  Churn Probability
# Cluster
# 0            32.051471        32.845761    1047.702141           0.120599
# 1            10.957752        71.961298     884.069671           0.691383
# 2            58.398884        90.430986    5278.001674           0.230647

# %% [markdown]
# 0 --> BUDGET LOYAL CUSTOMER
# 1 --> HIGH RISK NEW CUSTOMER
# 2--> LOYAL PREMIUM CUSTOMER

# %%
cluster_names={0:'Budget Loyal Customers',
1:'High Risk New Customers', 2:'Loyal Premium Customers'}

# %%
segmentation_data['Cluster Segment']=segmentation_data['Cluster'].map(cluster_names)

# %%
segmentation_data
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Churn Probability  \
# 0                 2            53.85         108.15           0.676963
# 1                 2            70.70         151.65           0.796013
# 2                 8            99.65         820.50           0.805827
# 3                28           104.80        3046.05           0.563031
# 4                49           103.70        5036.30           0.517474
# ...             ...              ...            ...                ...
# 7038             72            21.15        1419.40           0.003587
# 7039             24            84.80        1990.50           0.082095
# 7040             72           103.20        7362.90           0.049001
# 7041             11            29.60         346.45           0.302367
# 7042             66           105.65        6844.50           0.257647
#
#       Cluster          Cluster Segment
# 0           1  High Risk New Customers
# 1           1  High Risk New Customers
# 2           1  High Risk New Customers
# 3           1  High Risk New Customers
# 4           2  Loyal Premium Customers
# ...       ...                      ...
# 7038        0   Budget Loyal Customers
# 7039        0   Budget Loyal Customers
# 7040        2  Loyal Premium Customers
# 7041        0   Budget Loyal Customers
# 7042        2  Loyal Premium Customers
#
# [7043 rows x 6 columns]

# %%
plt.figure(figsize=(10,8))

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='Monthly Charges',y='Churn Probability',hue='Cluster Segment',data=segmentation_data,palette='Spectral')
plt.title('Customer Segmentation')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='Tenure Months',y='Churn Probability',hue='Cluster Segment',data=segmentation_data,palette='Spectral')
plt.title('Customer Segmentation')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='Total Charges',y='Churn Probability',hue='Cluster Segment',data=segmentation_data, palette='Spectral')
plt.title('Customer Segmentation')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='Tenure Months',y='Monthly Charges',hue='Cluster Segment',data=segmentation_data,palette='Spectral')
plt.title('Customer Segmentation')
plt.show()
